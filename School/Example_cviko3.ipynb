# %%
import numpy as np
import time
import scipy as sp
from scipy import special
import matplotlib.pyplot as plt
# %matplotlib inline

ti=time.clock()

data = np.loadtxt(
    "example_cviko.txt",
    skiprows = 1,
    unpack = True
)

data
# Out:
# array([[-8.00006569, -7.9969241 , -7.99378251, ...,  7.99378251,
#          7.9969241 ,  8.00006569],
#        [ 1.0079042 ,  1.00791049,  1.00791678, ...,  1.00791678,
#          1.00791049,  1.0079042 ],
#        [ 1.0079042 ,  1.00791048,  1.00791677, ...,  1.00791677,
#          1.00791048,  1.0079042 ],
#        [ 1.00790419,  1.00791048,  1.00791677, ...,  1.00791677,
#          1.00791048,  1.00790419],
#        [ 1.00790418,  1.00791046,  1.00791676, ...,  1.00791676,
#          1.00791046,  1.00790418],
#        [ 1.00790416,  1.00791045,  1.00791674, ...,  1.00791674,
#          1.00791045,  1.00790416]])

# %%
tab = data[0]

# %%
plt.figure(figsize=(10,5))
plt.xlim(-2,2)
plt.ylim(-0.5,5)

plt.xlabel(r'$ω$', fontsize = 15)
plt.ylabel(r'$N$', fontsize = 15)

line1, = plt.plot(data[0], data[1], linewidth = 3, label = r"$γ=0.1$")
line2, = plt.plot(data[0], data[2], linewidth = 3, label = r"$γ=0.3$")
line3, = plt.plot(data[0], data[3], linewidth = 3, label = r"$γ=0.5$")
line4, = plt.plot(data[0], data[4], linewidth = 3, label = r"$γ=0.7$")
line5, = plt.plot(data[0], data[5], linewidth = 3, label = r"$γ=0.9$")

plt.legend(handles=[line1,
                   line2,
                   line3,
                   line4,
                   line5], loc=1, fontsize=15)
plt.show()
